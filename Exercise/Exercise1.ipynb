# %% [markdown]
# # EXERCISE 1

# %% [markdown]
# 1. Load any stata file you have into a Pandas DataFrame, rename your file as
# “Results_b”, and display the first 4 rows. What is the size of the dataframe?

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd # this is for importing the libraries and executing the table
import seaborn as sns # this is for data visualizations
import numpy as np # this is for calculations
import matplotlib.pyplot as plt # this is running the graphics
pd.set_option('display.max_columns', None) #checking all columns

# %%
Results_b = pd.read_stata("C:\\Users\\I.Josh\\Documents\\Python_Tutorials\\cs_s1_s2_s3_s4_s6a_s6e_s6f_person.dta")
Results_b.head(4)
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 1  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 2  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 3  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 0  Replaced different household (dependent code 95)    11.0    13.0
# 1  Replaced different household (dependent code 95)    11.0    13.0
# 2  Replaced different household (dependent code 95)    11.0    13.0
# 3  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# 0  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
# 1  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
# ...

# %% [markdown]
# ### The size of the data frame

# %%
Results_b.shape
# Out:
# (66081, 127)

# %% [markdown]
# 2. Use the .describe() function to summarize the statistics of a numerical column from a
# dataset. What insights can you infer from the output?

# %%
Results_b.describe().round(2)            #summarize the statistics of a numerical column from a dataset.
# Out:
#             hhid    weight    s0q19m    s0q19y    pop_wt     clust   poverty  \
# count   66081.00  66081.00  66081.00  66081.00  63040.00  66081.00  66081.00
# mean   107236.82    173.00      6.74     13.75    705.03  10627.58      2.45
# std      4172.88     50.12      3.44      0.44    406.08    353.82      0.76
# min    100001.00     46.71      1.00     13.00     44.64  10001.00      1.00
# 25%    103618.00    151.18      4.00     13.00    429.12  10330.00      2.00
# 50%    107308.00    164.74      7.00     14.00    632.28  10638.00      3.00
# 75%    110856.00    182.02     10.00     14.00    900.47  10933.00      3.00
# max    114420.00    685.04     12.00     14.00   5816.00  11230.00      3.00
#
#        Consumption          pid     s1q3m         s2q1         s3q1  \
# count     66081.00     66081.00  10958.00     66025.00     66001.00
# mean     294923.56  10723685.71      5.00  10723729.59  10723746.79
# std      481185.00    417287.60      3.48    417282.21    417296.48
# ...

# %%
Results_b.describe(include = "all")  # summarize all statistical of all data frame categorical and numerical.
# Out:
#                  hhid           province district ur2012 ur2_2012  \
# count    66081.000000              66081    66081  66081    66081
# unique            NaN                  5       30      4        2
# top               NaN  Southern Province   Rusizi  Rural    Rural
# freq              NaN              17211     2426  50278    55497
# mean    107236.824307                NaN      NaN    NaN      NaN
# std       4172.876037                NaN      NaN    NaN      NaN
# min     100001.000000                NaN      NaN    NaN      NaN
# 25%     103618.000000                NaN      NaN    NaN      NaN
# 50%     107308.000000                NaN      NaN    NaN      NaN
# 75%     110856.000000                NaN      NaN    NaN      NaN
# max     114420.000000                NaN      NaN    NaN      NaN
#
#                 region        weight  \
# count            66081  66081.000000
# unique               6           NaN
# top     Rural Southern           NaN
# ...

# %% [markdown]
# 3. Rename the variables s1q1,s1q2,s1q3y and s3q3 as Sex, Relat_Hhead, Age, and
# Health_insurance respectively

# %%
stat_df = Results_b.copy()

# %%
stat_df.rename(columns = {'s1q1': 'Sex','s1q2':'Relat_Hhead','s1q3y':'Age','s3q3':'Health_insurance'}, inplace=True)
stat_df.head(2)
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 1  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 0  Replaced different household (dependent code 95)    11.0    13.0
# 1  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# 0  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
# 1  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
#
#           pid     Sex            Relat_Hhead   Age  s1q3m       s1q4  \
# 0  10000101.0  Female    Household head (HH)  33.0    NaN  Separated
# 1  10000102.0    Male  Son or daughter of HH  16.0    NaN     Single
#
#          s1q5      s1q6 s1q7      s1q8     s1q9 s1q10 s1q11 s1q12  \
# ...

# %% [markdown]
# ##### filter to get needed columns
# stat_df.filter(items = ['Sex','Relat_Hhead','Age','Health_insurance'])

# %% [markdown]
# ## 4. From the original dataframe, select the following variables:
# hhid','province','ur2_2012','quintile','poverty','Consumption', Sex, Relat_Hhead ','Age',
# and ‘Health_insurance’

# %%
stat_df1 = stat_df.loc[:,['hhid','province','ur2_2012','quintile','poverty','Consumption','Sex', 'Relat_Hhead','Age','Health_insurance']]
stat_df1.head(3)
# Out:
#        hhid     province ur2_2012 quintile  poverty   Consumption     Sex  \
# 0  100001.0  Kigali City    Urban       Q4      3.0  305390.90625  Female
# 1  100001.0  Kigali City    Urban       Q4      3.0  305390.90625    Male
# 2  100001.0  Kigali City    Urban       Q4      3.0  305390.90625    Male
#
#              Relat_Hhead   Age  Health_insurance
# 0    Household head (HH)  33.0  Mutual insurance
# 1  Son or daughter of HH  16.0  Mutual insurance
# 2  Son or daughter of HH  14.0  Mutual insurance

# %% [markdown]
# ## 5. Summarize the average Age or Consumption by Province and Urban_Rural.

# %%
summary = stat_df1.groupby(['province','ur2_2012'])[['Consumption','Age']].mean() # two square blacket bring dataframe.
summary
# Out:
# C:\Users\I.Josh\AppData\Local\Temp\ipykernel_14220\2836571742.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = stat_df1.groupby(['province','ur2_2012'])[['Consumption','Age']].mean() # two square blacket bring dataframe.
#                               Consumption        Age
# province          ur2_2012
# Kigali City       Urban     737101.312500  22.529837
#                   Rural     237922.296875  22.065499
# Southern Province Urban     771896.562500  23.459016
#                   Rural     228877.640625  24.076014
# Western Province  Urban     582593.750000  21.710889
#                   Rural     206761.031250  22.627237
# Northern Province Urban     661457.062500  23.234205
#                   Rural     199367.109375  23.362060
# ...

# %%
stat_df1['Age'] = stat_df1['Age'].astype('float') #Changing datatype of Age

# %%
summary = stat_df1.groupby(['province','ur2_2012']).agg(
    Mean_consumption =('Consumption','mean'),
    Mean_age =('Age','mean')
)
summary
# Out:
# C:\Users\I.Josh\AppData\Local\Temp\ipykernel_14220\1958481382.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = stat_df1.groupby(['province','ur2_2012']).agg(
#                             Mean_consumption   Mean_age
# province          ur2_2012
# Kigali City       Urban        737101.312500  22.529837
#                   Rural        237922.296875  22.065499
# Southern Province Urban        771896.562500  23.459016
#                   Rural        228877.640625  24.076014
# Western Province  Urban        582593.750000  21.710889
#                   Rural        206761.031250  22.627237
# Northern Province Urban        661457.062500  23.234205
#                   Rural        199367.109375  23.362060
# Eastern Province  Urban        573644.875000  22.427548
# ...

# %% [markdown]
# ## 6. Which commands that are used to detect outliers for the variable “Age”? run and
# interpreted the output.

# %%
outliers_plot = sns.boxplot(stat_df1.Age)
plt.subplots(1, 1)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
sex_by_Q = pd.crosstab(index = stat_df1['quintile'], columns = stat_df1['Sex'])
(sex_by_Q/sex_by_Q.sum()*100).round(2)
# Out:
# Sex        Male  Female
# quintile
# Q1        19.51   20.22
# Q2        19.65   20.42
# Q3        20.00   19.92
# Q4        19.86   19.80
# Q5        20.98   19.63

# %% [markdown]
# ## 8. Analyze the percentages of males and females by province and urban_rural
